# %% [markdown]
# Train mobel text representation using gbt

# %%
# Import pandas library
# Pandas is used to read and work with datasets
import pandas as pd  # Read the CSV dataset file
# Select only two columns from dataset

# %%
# Data loading
# common pre-processing
# nlp processing
# separate the data into features and labels x = input features, y = output labels
# data transformation (feature engineering)
# bags of words - count

# %%
# data loading
df = pd.read_csv('./cybersecurity_attacks.csv', encoding='latin-1')

# %%
# common pre-processing needed for nlp

# %%
# nlp processing

# %%
# separate the data into features and labels x= input features y= output labels

# %%
# data transformation(feature engineering)

# %%
# bags of words -
